# %%
#Advanced Text Preprocessing
import spacy
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_addons as tfa
import random
import nltk
import os
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import classification_report, roc_curve, roc_auc_score, confusion_matrix, accuracy_score, f1_score, cohen_kappa_score
from sklearn.model_selection import GroupKFold, train_test_split
from sklearn import tree, metrics

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from nltk.stem import PorterStemmer
from nltk.corpus import stopwords


random.seed(20)

# Load spaCy model for advanced tokenization and lemmatization
nlp = spacy.load('en_core_web_sm')

# Load dataset
df = pd.read_csv('/Users/emme/Desktop/annotation_final_features.csv')
column_names = df.columns
print(column_names)

# split data for student level cross validation: one student is nested within one fold
group_dict = dict()
groups = np.array([])

for index, row in df.iterrows():
    s_id = row['created_by']
    if s_id not in group_dict:
        group_dict[s_id] = index
    groups = np.append(groups, group_dict[s_id])
    
# Set up the splitter with 5 splits
gkf = GroupKFold(n_splits = 5)

# Function to preprocess text data
def preprocess_text(text):
    doc = nlp(text)
    tokens = [token.lemma_ for token in doc if not token.is_stop]
    return ' '.join(tokens)

# Apply preprocessing to the text data
df['preprocessed_text'] = df['annotation_text'].apply(preprocess_text)

# TF-IDF Vectorization
tfidf_vectorizer = TfidfVectorizer(max_features=1000)
X = tfidf_vectorizer.fit_transform(df['preprocessed_text']).toarray()
# Out:
# Index(['thinklet_id', 'problem_name', 'created_by', 'notify_to', 'created_at',
#        'annotation_text', 'relating_to_self', 'comment_answer',
#        'comment_process', 'count_nChar', 'count_nWords', 'contain_question',
#        'contain_plan', 'contain_addTransition', 'contain_advTransition',
#        'contain_causalTransition', 'contain_seqTransition', 'count_nNouns',
#        'count_nPronouns', 'count_nVerbs', 'count_nAdj', 'count_nAux',
#        'count_nCconj', 'count_nPunct', 'count_nSym', 'count_nFPP',
#        'contain_same', 'contain_answer', 'contain_correct', 'count_nPositive',
#        'count_nNegative'],
#       dtype='object')

# %%
#Neural Network Architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Neural network with additional layers and dropout
model = Sequential()
model.add(Dense(128, input_shape=(X.shape[1],), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#Training with Early Stopping and Hyperparameter Tuning
from tensorflow.keras.callbacks import EarlyStopping

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=5)

# stemming
porter = PorterStemmer() # stemming recovers root words from plurals etc
stemmed_texts = []

X_text = df['annotation_text']

for answer in X_text:
    answer = ' '.join(porter.stem(word) for word in answer.split(' '))
    stemmed_texts.append(answer)

X, y = np.array(stemmed_texts), df['relating_to_self'] # CHANGE y HERE

#vect = CountVectorizer(ngram_range=(1,1), max_features=1000, stop_words="english") #only unigram 313 features
vect = CountVectorizer(ngram_range=(2,2), max_features=1000, stop_words="english") #only bigram 728 features

X = vect.fit_transform(X).toarray()


# set up storage arrays for each round of validation
roc_auc_scores = np.array([])
accuracy_scores = np.array([])

# split, train, test and store performance metrics
for train_index, test_index in gkf.split(X, y, groups=groups):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    
    model = Sequential()
    model.add(Dense(12, input_shape=(738,), activation='relu')) 
    model.add(Dense(8, activation='relu')) 
    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss='binary_crossentropy', 
              optimizer='adam',
              metrics = ['acc']
             )
    
    num_epochs = 30
    batch_size = 10

    model.fit(
        X_train, 
        y_train, 
        epochs=num_epochs, 
        validation_split=0.1,
        shuffle=True, 
        batch_size=batch_size, callbacks=[early_stopping])
    
    predictions = model.predict(X_test)
    
    # compute some metrics and store them for averaging later on
    roc_auc_scores = np.append(roc_auc_scores, roc_auc_score(y_test, predictions))

# print mean scores for the 5-fold CV
print("average roc_auc score: ", np.round(roc_auc_scores.mean(), 3))
print("stdv roc_auc score: ", np.round(roc_auc_scores.std(), 3))
print("max roc_auc score: ", np.round(roc_auc_scores.max(), 3))
# Out:
# Epoch 1/30
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6785 - acc: 0.6768 - val_loss: 0.6681 - val_acc: 0.6842
# Epoch 2/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.6404 - acc: 0.7744 - val_loss: 0.6395 - val_acc: 0.7895
# Epoch 3/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.6015 - acc: 0.7805 - val_loss: 0.6071 - val_acc: 0.7895
# Epoch 4/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5591 - acc: 0.7683 - val_loss: 0.5735 - val_acc: 0.7895
# Epoch 5/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5109 - acc: 0.7866 - val_loss: 0.5389 - val_acc: 0.7895
# Epoch 6/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.4583 - acc: 0.8049 - val_loss: 0.5058 - val_acc: 0.7895
# Epoch 7/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.4064 - acc: 0.8659 - val_loss: 0.4729 - val_acc: 0.8421
# Epoch 8/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.3547 - acc: 0.8902 - val_loss: 0.4436 - val_acc: 0.8421
# Epoch 9/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.3078 - acc: 0.9024 - val_loss: 0.4174 - val_acc: 0.8421
# Epoch 10/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.2660 - acc: 0.9207 - val_loss: 0.3946 - val_acc: 0.8421
# Epoch 11/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.2269 - acc: 0.9451 - val_loss: 0.3748 - val_acc: 0.8421
# Epoch 12/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.1922 - acc: 0.9634 - val_loss: 0.3564 - val_acc: 0.8421
# Epoch 13/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.1627 - acc: 0.9756 - val_loss: 0.3383 - val_acc: 0.8421
# Epoch 14/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.1377 - acc: 0.9817 - val_loss: 0.3227 - val_acc: 0.8421
# Epoch 15/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.1169 - acc: 0.9817 - val_loss: 0.3063 - val_acc: 0.8421
# Epoch 16/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.1000 - acc: 0.9878 - val_loss: 0.2924 - val_acc: 0.8421
# Epoch 17/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0856 - acc: 0.9878 - val_loss: 0.2799 - val_acc: 0.8947
# Epoch 18/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0730 - acc: 0.9878 - val_loss: 0.2697 - val_acc: 0.8947
# Epoch 19/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0631 - acc: 0.9878 - val_loss: 0.2586 - val_acc: 0.8947
# Epoch 20/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0544 - acc: 0.9878 - val_loss: 0.2502 - val_acc: 0.8947
# Epoch 21/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0474 - acc: 0.9939 - val_loss: 0.2433 - val_acc: 0.8947
# Epoch 22/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0419 - acc: 0.9939 - val_loss: 0.2367 - val_acc: 0.9474
# Epoch 23/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0369 - acc: 1.0000 - val_loss: 0.2308 - val_acc: 0.9474
# Epoch 24/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0334 - acc: 1.0000 - val_loss: 0.2255 - val_acc: 0.9474
# Epoch 25/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0296 - acc: 1.0000 - val_loss: 0.2202 - val_acc: 0.9474
# Epoch 26/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.
30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0188 - acc: 1.0000 - val_loss: 0.1792 - val_acc: 0.9474
# 2/2 [==============================] - 0s 2ms/step
# Epoch 1/30
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6591 - acc: 0.8061 - val_loss: 0.6195 - val_acc: 0.8947
# Epoch 2/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.6161 - acc: 0.8424 - val_loss: 0.5811 - val_acc: 0.9474
# Epoch 3/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5644 - acc: 0.8970 - val_loss: 0.5402 - val_acc: 0.9474
# Epoch 4/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5062 - acc: 0.9212 - val_loss: 0.4934 - val_acc: 0.9474
# Epoch 5/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.4393 - acc: 0.9394 - val_loss: 0.4467 - val_acc: 0.9474
# Epoch 6/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.3708 - acc: 0.9394 - val_loss: 0.3990 - val_acc: 0.9474
# Epoch 7/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.3046 - acc: 0.9636 - val_loss: 0.3578 - val_acc: 0.9474
# Epoch 8/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.2461 - acc: 0.9697 - val_loss: 0.3223 - val_acc: 0.9474
# Epoch 9/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.1974 - acc: 0.9879 - val_loss: 0.2923 - val_acc: 0.9474
# Epoch 10/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.1593 - acc: 0.9879 - val_loss: 0.2711 - val_acc: 0.9474
# Epoch 11/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.1279 - acc: 0.9879 - val_loss: 0.2505 - val_acc: 0.9474
# Epoch 12/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.1049 - acc: 0.9879 - val_loss: 0.2377 - val_acc: 0.9474
# Epoch 13/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0868 - acc: 0.9879 - val_loss: 0.2242 - val_acc: 0.9474
# Epoch 14/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0723 - acc: 0.9879 - val_loss: 0.2164 - val_acc: 0.9474
# Epoch 15/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0615 - acc: 0.9939 - val_loss: 0.2097 - val_acc: 0.9474
# Epoch 16/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0522 - acc: 0.9939 - val_loss: 0.2018 - val_acc: 0.9474
# Epoch 17/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0450 - acc: 0.9939 - val_loss: 0.1961 - val_acc: 0.9474
# Epoch 18/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0391 - acc: 1.0000 - val_loss: 0.1929 - val_acc: 0.9474
# Epoch 19/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0344 - acc: 1.0000 - val_loss: 0.1885 - val_acc: 0.9474
# Epoch 20/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0304 - acc: 1.0000 - val_loss: 0.1853 - val_acc: 0.9474
# Epoch 21/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0270 - acc: 1.0000 - val_loss: 0.1827 - val_acc: 0.9474
# Epoch 22/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0241 - acc: 1.0000 - val_loss: 0.1801 - val_acc: 0.9474
# Epoch 23/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0217 - acc: 1.0000 - val_loss: 0.1785 - val_acc: 0.9474
# Epoch 24/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0195 - acc: 1.0000 - val_loss: 0.1764 - val_acc: 0.9474
# Epoch 25/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0177 - acc: 1.0000 - val_loss: 0.1748 - val_acc: 0.9474
# Epoch 26/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0163 - acc: 1.0000 - val_loss: 0.1738 - val_acc: 0.9474
# Epoch 27/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0147 - acc: 1.0000 - val_loss: 0.1727 - val_acc: 0.9474
# Epoch 28/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0136 - acc: 1.0000 - val_loss: 0.1722 - val_acc: 0.9474
# Epoch 29/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0124 - acc: 1.0000 - val_loss: 0.1706 - val_acc: 0.9474
# Epoch 30/30
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0115 - acc: 1.0000 - val_loss: 0.1697 - val_acc: 0.9474
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2922481f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 930us/step
# average roc_auc score:  0.929
# stdv roc_auc score:  0.023
# max roc_auc score:  0.958
